# %%
comments = """
### Положительные отзывы:

1. **"Невероятная еда и обслуживание!"**  
   Каждое блюдо было восхитительным, а персонал сделал всё, чтобы мы чувствовали себя комфортно. Вернусь обязательно!

2. **"Лучший ресторан в городе!"**  
   Интерьер потрясающий, еда приготовлена идеально, и атмосфера очень уютная. Великолепный опыт!

3. **"Превосходный ужин с семьёй"**  
   Отличный выбор для семейных ужинов. Блюда разнообразные и очень вкусные, а обслуживание выше всяких похвал.

4. **"Свежие ингредиенты и быстрая подача"**  
   Все продукты были свежими, а блюда подали очень быстро. Настоящее удовольствие от еды!

5. **"Потрясающие десерты"**  
   Особенно понравились десерты! Чизкейк просто волшебный, и сервировка впечатляет.

---

### Негативные отзывы:

1. **"Очень долгое обслуживание"**  
   Ждали свои блюда почти час, и это в ресторане с половиной пустых столов. Разочарованы!

2. **"Не оправдали ожиданий"**  
   Еда средняя, ничего особенного. За такую цену ожидали большего. Очень громкая музыка, было сложно разговаривать.

3. **"Неудовлетворительное качество блюд"**  
   Стейки были переварены, а гарнир холодным. Ожидал куда большего от заведения с такой репутацией.

4. **"Отсутствие вежливости у персонала"**  
   Официанты были не внимательны и грубы, заказ приносили с ошибками. Совсем не то, чего хотелось от ужина.

5. **"Неприятный запах и грязные столы"**  
   Когда пришли, в зале стоял неприятный запах, а столы были плохо убраны. Ушли, не сделав заказа.

---

### Нейтральные отзывы:

1. **"Неплохой ресторан, но без вау-эффекта"**  
   Еда была вкусной, но ничего особенного. Обычное место для быстрого ужина, без особого впечатления.

2. **"Хорошо, но есть куда стремиться"**  
   В целом неплохо: еда хорошая, но обслуживание немного медленное. Можно улучшить.

3. **"Средний опыт"**  
   Посетил ресторан по рекомендации. Нормальная еда, ничего выдающегося. Не плохо, но не на 5 звёзд.

4. **"Понравилась атмосфера, но есть нюансы"**  
   Интерьер и атмосфера отличные, но еда могла быть лучше. Цена не совсем соответствует качеству.

5. **"Были один раз, возможно вернёмся"**  
   В общем, всё устроило, но ничего, что бы заставило вернуться как можно скорее. Обычное место.

"""

# %%
Task: write a function, which recieve string of different type of comments(negative,positive,neut)
